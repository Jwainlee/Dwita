# %% [markdown]
# <a href="https://colab.research.google.com/github/Jwainlee/Dwita/blob/main/project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('/content/drive/MyDrive/data/연령.csv')

# %%
df.head()
# Out:
#                             행정구역 2018년_계_총인구수 2018년_계_0~9세 2018년_계_10~19세  \
# 0     경상남도 경상남도 밀양시 (4827000000)      106,744        6,212          8,634
# 1      경상남도 밀양시 삼랑진읍(4827025000)        5,643          164            285
# 2  경상남도 밀양시 삼랑진임천출장소(4827025100)        1,332           24             64
# 3       경상남도 밀양시 하남읍(4827025300)        7,653          322            506
# 4       경상남도 밀양시 부북면(4827031000)        5,702          202            307
#
#   2018년_계_20~29세 2018년_계_30~39세 2018년_계_40~49세 2018년_계_50~59세 2018년_계_60~69세  \
# 0          9,900          9,999         13,686         19,824         19,149
# 1            408            385            600          1,128          1,285
# 2            125             79            123            247            296
# 3            663            625            834          1,472          1,547
# 4            457            442            574          1,136          1,239
#
# ...

# %%
df.index = df.iloc[:,0]
df = df.iloc[:,1::]

# %%
df.head()
# Out:
#                               2018년_계_총인구수 2018년_계_0~9세 2018년_계_10~19세  \
# 행정구역
# 경상남도 경상남도 밀양시 (4827000000)         106,744        6,212          8,634
# 경상남도 밀양시 삼랑진읍(4827025000)            5,643          164            285
# 경상남도 밀양시 삼랑진임천출장소(4827025100)        1,332           24             64
# 경상남도 밀양시 하남읍(4827025300)             7,653          322            506
# 경상남도 밀양시 부북면(4827031000)             5,702          202            307
#
#                               2018년_계_20~29세 2018년_계_30~39세 2018년_계_40~49세  \
# 행정구역
# 경상남도 경상남도 밀양시 (4827000000)             9,900          9,999         13,686
# 경상남도 밀양시 삼랑진읍(4827025000)                408            385            600
# 경상남도 밀양시 삼랑진임천출장소(4827025100)            125             79            123
# 경상남도 밀양시 하남읍(4827025300)                 663            625            834
# 경상남도 밀양시 부북면(4827031000)                 457            442            574
#
# ...

# %%
for col in df.columns:
  if df[col].dtype != 'int':
    df[col] = df[col].str.replace(',', '').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 경상남도 경상남도 밀양시 (4827000000) to 경상남도 밀양시 교동(4827055000)
# Data columns (total 60 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   2018년_계_총인구수     18 non-null     int64
#  1   2018년_계_0~9세     18 non-null     int64
#  2   2018년_계_10~19세   18 non-null     int64
#  3   2018년_계_20~29세   18 non-null     int64
#  4   2018년_계_30~39세   18 non-null     int64
#  5   2018년_계_40~49세   18 non-null     int64
#  6   2018년_계_50~59세   18 non-null     int64
#  7   2018년_계_60~69세   18 non-null     int64
#  8   2018년_계_70~79세   18 non-null     int64
#  9   2018년_계_80~89세   18 non-null     int64
#  10  2018년_계_90~99세   18 non-null     int64
#  11  2018년_계_100세 이상  18 non-null     int64
#  12  2019년_계_총인구수     18 non-null     int64
#  13  2019년_계_0~9세     18 non-null     int64
#  14  2019년_계_10~19세   18 non-null     int64
#  15  2019년_계_20~29세   18 non-null     int64
# ...

# %%
df_2018 = df.iloc[0,0:12]
df_2019 = df.iloc[0,12:24]
df_2020 = df.iloc[0,24:36]
df_2021 = df.iloc[0,36:48]
df_2022 = df.iloc[0,48:60]

# %%
df_2018.values
# Out:
# array([106744,   6212,   8634,   9900,   9999,  13686,  19824,  19149,
#         12229,   6337,    740,     34])

# %%
df_2018.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 12 entries, 2018년_계_총인구수 to 2018년_계_100세 이상
# Series name: 경상남도 경상남도 밀양시 (4827000000)
# Non-Null Count  Dtype
# --------------  -----
# 12 non-null     int64
# dtypes: int64(1)
# memory usage: 192.0+ bytes

# %%
plt.plot(df_2018)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# ...
